# %%
# !pip install SimpleITK opencv-python -q

# %%
import numpy as np
import pandas as pd
import cv2
import SimpleITK as sitk
import matplotlib.pyplot as plt
from pathlib import Path
from typing import List, Tuple
import math

BASE_DIR = Path("./project_data")
RAW_ATLAS_DIR = BASE_DIR / "raw_atlas_slices"
SYNTHETIC_TEST_DIR = BASE_DIR / "test_synthetic"
gt_df = pd.read_csv(SYNTHETIC_TEST_DIR / "ground_truth.csv")

# %% [markdown]
# ### 🔍 Function for Finding the Most Similar Brain Slice (Mutual Information Registration)

# %%
def find_most_similar_slices(query_slice, atlas_dir):
    """Find the most similar slice from a reference atlas directory based on Mutual Information (MI)."""

    # Adjustable parameters
    DOWNSAMPLE_FACTOR = 2       # Downsample to accelerate (>1 means smaller)
    HIST_BINS = 64              # Number of bins for the mutual information histogram
    SAMPLE_PERCENT = 0.2        # Sampling ratio for mutual information (used during registration)
    MAX_ITER = 150              # Maximum number of iterations per slice
    ROT_RANGE_DEG = 20          # Allowable small-angle perturbation (helps avoid local minima)

    # Convert numpy grayscale image to SimpleITK image and optionally downsample
    def to_sitk_gray(img_np, down=1):
        if down > 1:
            img_np = cv2.resize(
                img_np,
                (img_np.shape[1] // down, img_np.shape[0] // down),
                interpolation=cv2.INTER_AREA
            )
        return sitk.GetImageFromArray(img_np.astype(np.float32))

    # Generate binary mask (ignore pure black background)
    def make_mask(img_np, down=1, thresh=0, min_pixels=50):
        # Use ">0" as foreground to preserve weak gray values
        if down > 1:
            img_np = cv2.resize(
                img_np,
                (img_np.shape[1] // down, img_np.shape[0] // down),
                interpolation=cv2.INTER_NEAREST
            )
        mask = (img_np > thresh).astype(np.uint8)
        if mask.sum() < min_pixels:
            return None  # Skip if too few valid pixels
        return sitk.GetImageFromArray(mask)

    # Compute Normalized Mutual Information (NMI)
    def normalized_mutual_information(x, y, mask=None, bins=64):
        x = x.astype(np.float32).ravel()
        y = y.astype(np.float32).ravel()
        if mask is not None:
            m = mask.astype(bool).ravel()
            if m.sum() == 0:
                return -np.inf
            x = x[m]
            y = y[m]

        # Adaptive intensity range (exclude extreme background)
        x_min, x_max = np.percentile(x, 1), np.percentile(x, 99)
        y_min, y_max = np.percentile(y, 1), np.percentile(y, 99)
        x = np.clip(x, x_min, x_max)
        y = np.clip(y, y_min, y_max)

        # Joint histogram
        H, _, _ = np.histogram2d(x, y, bins=bins)
        Pxy = H / np.maximum(H.sum(), 1.0)
        Px = Pxy.sum(axis=1, keepdims=True)
        Py = Pxy.sum(axis=0, keepdims=True)

        # Avoid log(0)
        eps = 1e-12
        Hx = -np.sum(Px * np.log(Px + eps))
        Hy = -np.sum(Py * np.log(Py + eps))
        Hxy = -np.sum(Pxy * np.log(Pxy + eps))

        # Strehl & Ghosh definition; higher = more similar
        return (Hx + Hy) / max(Hxy, eps)

    # Perform registration and compute NMI score
    def register_and_score(fixed_np, moving_np, hist_bins=HIST_BINS,
                           sample_percent=SAMPLE_PERCENT, max_iter=MAX_ITER,
                           down=DOWNSAMPLE_FACTOR) -> Tuple[float, sitk.Transform, np.ndarray, np.ndarray]:

        fixed_img = to_sitk_gray(fixed_np, down=down)
        moving_img = to_sitk_gray(moving_np, down=down)

        fixed_mask = make_mask(fixed_np, down=down, thresh=0)
        moving_mask = make_mask(moving_np, down=down, thresh=0)

        def _run(mask_fixed, mask_moving, sampling='RANDOM'):
            reg = sitk.ImageRegistrationMethod()
            reg.SetMetricAsMattesMutualInformation(numberOfHistogramBins=hist_bins)

            if sampling == 'RANDOM':
                reg.SetMetricSamplingStrategy(reg.RANDOM)
                reg.SetMetricSamplingPercentage(sample_percent)
            else:
                reg.SetMetricSamplingStrategy(reg.NONE)

            if mask_fixed is not None:
                reg.SetMetricFixedMask(mask_fixed)
            if mask_moving is not None:
                reg.SetMetricMovingMask(mask_moving)

            reg.SetInterpolator(sitk.sitkLinear)
            reg.SetShrinkFactorsPerLevel([4, 2, 1])
            reg.SetSmoothingSigmasPerLevel([2, 1, 0])
            reg.SmoothingSigmasAreSpecifiedInPhysicalUnitsOn()

            # Initialize transform (similarity)
            initial_tx = sitk.CenteredTransformInitializer(
                fixed_img,
                moving_img,
                sitk.Similarity2DTransform(),
                sitk.CenteredTransformInitializerFilter.GEOMETRY
            )

            if ROT_RANGE_DEG > 0:
                angle_rad = np.deg2rad(np.random.uniform(-ROT_RANGE_DEG, ROT_RANGE_DEG))
                initial_tx.SetAngle(initial_tx.GetAngle() + float(angle_rad))

            reg.SetOptimizerAsRegularStepGradientDescent(
                learningRate=2.0,
                minStep=1e-3,
                numberOfIterations=max_iter,
                relaxationFactor=0.5,
                gradientMagnitudeTolerance=1e-6
            )
            reg.SetOptimizerScalesFromPhysicalShift()
            reg.SetInitialTransform(initial_tx, inPlace=False)
            final_tx = reg.Execute(fixed_img, moving_img)
            moved = sitk.Resample(moving_img, fixed_img, final_tx, sitk.sitkLinear, 0.0, sitk.sitkFloat32)
            return final_tx, moved

        # 1) Preferred: with mask + random sampling
        try:
            final_tx, moved = _run(fixed_mask, moving_mask, sampling='RANDOM')
        except Exception:
            # 2) Fallback: no mask
            try:
                final_tx, moved = _run(None, None, sampling='RANDOM')
            except Exception:
                # 3) Final fallback: no sampling (full image)
                final_tx, moved = _run(None, None, sampling='NONE')

        moved_np = sitk.GetArrayFromImage(moved)
        fixed_np_ds = sitk.GetArrayFromImage(fixed_img)

        joint_mask = ((moved_np > 0) & (fixed_np_ds > 0)).astype(np.uint8)
        nmi = normalized_mutual_information(fixed_np_ds, moved_np, mask=joint_mask, bins=hist_bins)
        return nmi, final_tx, moved_np, fixed_np_ds

    # Load all candidate slices from atlas_dir
    exts = (".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp")
    atlas_paths: List[Path] = [p for p in atlas_dir.glob("**/*") if p.suffix.lower() in exts]

    if len(atlas_paths) == 0:
        raise RuntimeError(f"No image files found in {atlas_dir}.")

    # Ensure query_slice is uint8
    query_np = query_slice.copy()
    if query_np.dtype != np.uint8:
        query_np = query_np.astype(np.uint8)

    scores: List[Tuple[float, Path]] = []
    best_result = {}

    print(f"Number of candidate slices: {len(atlas_paths)}")
    for i, atlas_path in enumerate(atlas_paths, 1):
        # Read candidate atlas slice
        atlas_np = cv2.imread(str(atlas_path), cv2.IMREAD_GRAYSCALE)
        if atlas_np is None:
            continue

        # Resize to roughly match the query slice size (improves convergence)
        scale = min(query_np.shape[0] / atlas_np.shape[0], query_np.shape[1] / atlas_np.shape[1])
        if scale < 0.5 or scale > 2.0:
            new_wh = (
                max(8, int(atlas_np.shape[1] * scale)),
                max(8, int(atlas_np.shape[0] * scale))
            )
            atlas_resized = cv2.resize(
                atlas_np, new_wh,
                interpolation=cv2.INTER_AREA if scale < 1 else cv2.INTER_LINEAR
            )
        else:
            atlas_resized = atlas_np

        try:
            nmi, transform, moved_np, fixed_np_ds = register_and_score(atlas_resized, query_np)
            scores.append((nmi, atlas_path))
            if len(best_result) == 0 or nmi > best_result["nmi"]:
                best_result = {
                    "nmi": nmi,
                    "path": atlas_path,
                    "fixed": fixed_np_ds,
                    "moved": moved_np
                }
        except Exception as e:
            print(f"[{i}/{len(atlas_paths)}] Skipped {atlas_path.name}: {e}")
            continue

    # Return best matched slice and its visualization info
    return best_result

# %% [markdown]
# ### 🧩 Batch mutual information matching and Evaluate Slice Matching Accuracy (Mutual Information Retrieval)

# %%
# --- 3. Batch execution of Mutual Information matching ---
import re
results = []
x, y = 0, 0  # x = number of correct matches, y = total samples


# A is the ground-truth original slice numpy array (source of the synthetic image).
# A1 is the synthetic image generated from A (rotated, shifted, or deformed version).
# A2 is the best-matched slice filename predicted by the algorithm.
# a is the numeric index extracted from A (true slice number).
# a2 is the numeric index extracted from A2 (predicted slice number).

for i, row in gt_df.iterrows():

    print(f"\n=== Processing test image {i+1}/{len(gt_df)} ===")

    # Get test image path
    A1_path = SYNTHETIC_TEST_DIR / "images" / row["synthetic_file"]
    
    A = Path(row["source_file"]).name        # Use only filename for reliable comparison

    # Load grayscale image (A is not needed for computation, kept for consistency)
    A1 = cv2.imread(str(A1_path), cv2.IMREAD_GRAYSCALE)

    if A1 is None or (np.sum(A1 < 15) / A1.size > 0.90):
        print(f"⚠️ Cannot read {A1_path.name}, skipping.")
        continue

    # Run matching function and get best match visualization info
    best_vis = find_most_similar_slices(A1, RAW_ATLAS_DIR)

    # Extract returned info (best_vis must contain 'path' and 'nmi')
    A2 = best_vis['path'].name
    a = int(re.search(r'\d+', A).group())
    a2 = int(re.search(r'\d+', A2).group())

    # Statistics
    y += 1
    is_correct = (abs(a - a2) <= 4)
    if is_correct:
        x += 1
    
    # Record results
    results.append({
        "synthetic_file": row["synthetic_file"],
        "best_match": A2,
        "gt_source_file": A,
        "correct": bool(is_correct)
    })

    # ✅ Print variable values (handle None cases for best_vis safely)
    print(f"Prediction: {A2} | Ground Truth: {A}")
    print(f"current Accuracy: {x}/{y} = {x / y:.3f}")

# Print final accuracy
if y > 0:
    print(f"\nFinal Accuracy: {x}/{y} = {x / y:.3f}")
else:
    print("\nNo valid samples were processed.")

# --- Save results ---
results_df = pd.DataFrame(results)
results_df.to_csv(SYNTHETIC_TEST_DIR / "match_results.csv", index=False)
print("\n✅ All test images processed successfully. Results saved to match_results.csv.")
# Out:
# === Processing test image 1/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F2AF40): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83338]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190123CC240): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83338]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190414A5B30): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83338]
# Prediction: sagittal_slice_090.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 0/1 = 0.000
#
# === Processing test image 2/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041668090): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.80199]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019010F422C0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.80199]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190414A8510): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.80199]
# Prediction: sagittal_slice_360.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 0/2 = 0.000
#
# === Processing test image 3/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190126CEBC0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86259]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041692860): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86259]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190417A1860): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86259]
# Prediction: sagittal_slice_350.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 0/3 = 0.000
#
# === Processing test image 4/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041397ED0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.84246]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904275A260): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.84246]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190417A1860): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.84246]
# Prediction: sagittal_slice_380.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 0/4 = 0.000
#
# === Processing test image 5/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190424FD9B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88825]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F95610): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88825]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190126CE800): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88825]
# Prediction: sagittal_slice_090.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 0/5 = 0.000
#
# === Processing test image 6/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904122AF40): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83129]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041005E70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83129]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904254AEA0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83129]
# Prediction: sagittal_slice_360.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 0/6 = 0.000
#
# === Processing test image 7/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190417A2B20): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.8348]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410074F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.8348]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F82840): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.8348]
# Prediction: sagittal_slice_100.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 1/7 = 0.143
#
# === Processing test image 8/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190427B23D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.78074]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F82DE0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.78074]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904162AA60): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.78074]
# Prediction: sagittal_slice_360.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 1/8 = 0.125
#
# === Processing test image 9/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041386BB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86349]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410C9AB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86349]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190427B6290): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86349]
# Prediction: sagittal_slice_360.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 1/9 = 0.111
#
# === Processing test image 10/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041615300): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.77693]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904134C3B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.77693]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904108B400): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.77693]
# Prediction: sagittal_slice_100.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/10 = 0.200
#
# === Processing test image 11/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041005C90): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88443]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904137C390): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88443]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190414C5CA0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88443]
# Prediction: sagittal_slice_350.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/11 = 0.182
#
# === Processing test image 12/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040FAE890): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.82531]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041389A30): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.82531]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190413EC370): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.82531]
# Prediction: sagittal_slice_360.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/12 = 0.167
#
# === Processing test image 13/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190411E7130): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83691]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041397CF0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83691]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041172530): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.83691]
# Prediction: sagittal_slice_380.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/13 = 0.154
#
# === Processing test image 14/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019042757FB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.78825]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041397930): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.78825]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190424E2790): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.78825]
# Prediction: sagittal_slice_060.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/14 = 0.143
#
# === Processing test image 15/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019042754700): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86374]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041312540): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86374]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190424FEC70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.86374]
# Prediction: sagittal_slice_120.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/15 = 0.133
#
# === Processing test image 16/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904137B490): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.81483]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019010F42E00): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.81483]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415E5690): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.81483]
# Prediction: sagittal_slice_380.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 2/16 = 0.125
#
# === Processing test image 17/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040FAFD30): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88647]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904123AC80): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88647]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190426F5D40): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.88647]
# Prediction: sagittal_slice_100.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 3/17 = 0.176
#
# === Processing test image 18/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415301A0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.8438]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416931C0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.8438]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019010F42C20): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.8438]
# Prediction: sagittal_slice_360.png | Ground Truth: sagittal_slice_100.png
# current Accuracy: 3/18 = 0.167
#
# === Processing test image 19/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904137C390): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.011]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904141CA00): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.011]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416123B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.011]
# Prediction: coronal_slice_004.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/19 = 0.158
#
# === Processing test image 20/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410E0750): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.97236]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904164F2B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.97236]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190426F5950): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.97236]
# Prediction: horizontal_slice_048.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/20 = 0.150
#
# === Processing test image 21/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041497E70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03231]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904253AA30): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03231]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041561F10): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03231]
# Prediction: coronal_slice_004.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/21 = 0.143
#
# === Processing test image 22/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904151F8E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.01514]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904138DD70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.01514]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F91DC0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.01514]
# Prediction: coronal_slice_468.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/22 = 0.136
#
# === Processing test image 23/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904122A7C0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05147]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904138C6F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05147]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019042C77F50): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05147]
# Prediction: coronal_slice_080.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/23 = 0.130
#
# === Processing test image 24/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F850F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.01814]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415AB4F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.01814]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190413892B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.01814]
# Prediction: coronal_slice_492.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/24 = 0.125
#
# === Processing test image 25/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410B6DD0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00982]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904162A6D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00982]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041498B90): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00982]
# Prediction: horizontal_slice_208.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/25 = 0.120
#
# === Processing test image 26/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904122B4E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.9538]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F94CB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.9538]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904172CBB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.9538]
# Prediction: horizontal_slice_048.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 3/26 = 0.115
#
# === Processing test image 27/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904164F0D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03238]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415C0F70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03238]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041239BA0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03238]
# Prediction: horizontal_slice_224.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 4/27 = 0.148
#
# === Processing test image 28/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190411944E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.99292]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416A69E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.99292]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416A3CC0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.99292]
# Prediction: horizontal_slice_224.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 5/28 = 0.179
#
# === Processing test image 29/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019042C43DD0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05096]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041083F70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05096]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190126CD720): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05096]
# Prediction: horizontal_slice_216.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 5/29 = 0.172
#
# === Processing test image 30/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041195F20): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00625]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904151F510): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00625]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041007310): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00625]
# Prediction: horizontal_slice_224.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/30 = 0.200
#
# === Processing test image 31/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416A49E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00947]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415B44B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00947]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904179BB70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.00947]
# Prediction: coronal_slice_080.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/31 = 0.194
#
# === Processing test image 32/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190417A1C20): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.98302]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041310320): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.98302]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190417A1C20): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.98302]
# Prediction: horizontal_slice_048.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/32 = 0.188
#
# === Processing test image 33/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410E0CF0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.0316]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904138AB10): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.0316]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190409B16A0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.0316]
# Prediction: coronal_slice_080.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/33 = 0.182
#
# === Processing test image 34/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416A7AC0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.99015]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410E0930): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.99015]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040FB0190): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 1.99015]
# Prediction: horizontal_slice_056.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/34 = 0.176
#
# === Processing test image 35/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904138A750): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05032]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904272DF50): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05032]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416A8420): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.05032]
# Prediction: coronal_slice_004.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/35 = 0.171
#
# === Processing test image 36/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190417879F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03883]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040FEEE10): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03883]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041082AD0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.03883]
# Prediction: coronal_slice_440.png | Ground Truth: horizontal_slice_224.png
# current Accuracy: 6/36 = 0.167
#
# === Processing test image 37/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F94530): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.56758]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190409B25A0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.56758]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904104D450): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.56758]
# Prediction: coronal_slice_092.png | Ground Truth: horizontal_slice_144.png
# current Accuracy: 6/37 = 0.162
#
# === Processing test image 38/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040FEEA50): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.50901]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041788F50): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.50901]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190412835B0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.50901]
# Prediction: horizontal_slice_056.png | Ground Truth: horizontal_slice_144.png
# current Accuracy: 6/38 = 0.158
#
# === Processing test image 39/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190424FD050): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.59621]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041788D70): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.59621]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190414F9580): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.59621]
# Prediction: coronal_slice_004.png | Ground Truth: horizontal_slice_144.png
# current Accuracy: 6/39 = 0.154
#
# === Processing test image 40/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041282C50): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 2.55943]
# ...
#
# === Processing test image 708/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019042B1C7A0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.46314]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041082530): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.46314]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F92720): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.46314]
# Prediction: coronal_slice_004.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 246/663 = 0.371
#
# === Processing test image 709/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190409B24F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.37034]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190411FDA90): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.37034]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190414273E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.37034]
# Prediction: coronal_slice_308.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 247/664 = 0.372
#
# === Processing test image 710/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410BD780): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.33342]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041642BB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.33342]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904117D0F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.33342]
# Prediction: coronal_slice_304.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 248/665 = 0.373
#
# === Processing test image 711/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190427ECBB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.45411]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190126CEF80): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.45411]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019010F43580): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.45411]
# Prediction: coronal_slice_308.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 249/666 = 0.374
#
# === Processing test image 712/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041692860): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.41083]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041239CD0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.41083]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415BDD60): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.41083]
# Prediction: coronal_slice_308.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 250/667 = 0.375
#
# === Processing test image 713/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904106A2F0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.51482]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190126CDCC0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.51482]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041389850): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.51482]
# Prediction: coronal_slice_304.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 251/668 = 0.376
#
# === Processing test image 714/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190427DCEF0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.47195]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190425D1260): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.47195]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190416A3900): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.47195]
# Prediction: coronal_slice_312.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/669 = 0.377
#
# === Processing test image 715/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190415E53E0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.36609]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041128FB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.36609]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904164E1D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.36609]
# Prediction: coronal_slice_012.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/670 = 0.376
#
# === Processing test image 716/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001904108AE60): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.32826]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019042B5B090): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.32826]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041194E40): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.32826]
# Prediction: coronal_slice_192.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/671 = 0.376
#
# === Processing test image 717/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190410BDF60): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.45327]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041128FB0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.45327]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190413E6840): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.45327]
# Prediction: coronal_slice_284.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/672 = 0.375
#
# === Processing test image 718/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040FF1B50): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.41073]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190412824D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.41073]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041083070): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.41073]
# Prediction: coronal_slice_336.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/673 = 0.374
#
# === Processing test image 719/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190413BCFF0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.53166]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(000001901264C1D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.53166]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F82FC0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.53166]
# Prediction: coronal_slice_004.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/674 = 0.374
#
# === Processing test image 720/720 ===
# Number of candidate slices: 218
# [1/218] Skipped coronal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019041508670): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.47216]
# [133/218] Skipped horizontal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(00000190412824D0): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.47216]
# [173/218] Skipped sagittal_slice_000.png: Exception thrown in SimpleITK ImageRegistrationMethod_Execute: D:\a\SimpleITK\SimpleITK\bld\ITK-prefix\include\ITK-5.4\itkImageBase.hxx:79:
# ITK ERROR: Image(0000019040F27C90): Zero-valued spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [0, 3.47216]
# Prediction: coronal_slice_300.png | Ground Truth: coronal_slice_308.png
# current Accuracy: 252/675 = 0.373
#
# Final Accuracy: 252/675 = 0.373
#
# ✅ All test images processed successfully. Results saved to match_results.csv.
